# %%
import sys, os
from pyspark.sql import SparkSession

# %%
spark.sparkContext.addPyFile('/Workspace/Users/de.lopezbarron@gmail.com/databricks-experiments/src/spark_custom_io.py')

# %%
# %pip install /Workspace/Users/de.lopezbarron@gmail.com/databricks-experiments/src/spark_custom_io

# %%
import sys, os
sys.path.append(os.path.abspath('/Workspace/Users/de.lopezbarron@gmail.com/databricks-experiments/src'))

from pyspark.sql import SparkSession
from spark_custom_io import *

spark = SparkSession.builder.appName("CustomWriterExample").getOrCreate()
spark.dataSource.register(CustomDataSource) # Register custom source

data = [("Alice", 25), ("Bob", 30)]
df = spark.createDataFrame(data, ["name", "age"])

df.write.format("customconsole").mode("append").option("prefix", "LOG:").option("outputPath", "/Volumes/workspace/testing_schema/testing_volumne/t2").save()
